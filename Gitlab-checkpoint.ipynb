# %% [markdown]
# ## TOC:
# * [Description](#first-bullet)
# * [image 1](#second-bullet)
# * [image 2](#third-bullet)
# * [favourites things in destination](#fourth-bullet)
# * [text color](#fifth-bullet)
# * [bold](#sixth-bullet)
# * [link youtube](#seventh-bullet)

# %% [markdown]
# # Description <a class="anchor" id="first-bullet"></a>

# %%
#this is my first user function
a=input('Please enter person name')
# Out:
# Please enter person nameSivan

# %% [markdown]
# # image 1 <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# # image 2 <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# ![Eiffel-Tower-Paris.webp](attachment:Eiffel-Tower-Paris.webp)

# %% [markdown]
# # favourites things in destination <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# favourites things in destination=["site seeing","pictue taking","trvelling"]

# %% [markdown]
# # text color<a class="anchor" id="first-bullet"></a>

# %% [markdown]
# <h1 style="color:green;">text</h1>

# %% [markdown]
# font color=green>green text</font>

# %% [markdown]
# # bold<a class="anchor" id="first-bullet"></a>

# %% [markdown]
# **bold Nandhini**

# %% [markdown]
# *bold Nandhini*

# %% [markdown]
# # link youtube <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# nice place to visit[Youtube] (https://youtu.be/su_TfI6_Io8)
